# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.figsize']= (20,10)

# %%
df1 = pd.read_csv('train.csv')
df1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df1.shape
# Out:
# (1460, 81)

# %%
df2 = df1.drop(['MSZoning','Alley','PoolQC','LotFrontage','LotShape','LotConfig','Condition2','RoofMatl','Exterior2nd','BsmtQual','BsmtFinType2','BsmtUnfSF','LowQualFinSF','BsmtHalfBath','BsmtFullBath','Functional','FireplaceQu','GarageYrBlt','GarageFinish','GarageArea','GarageQual','BsmtExposure','BsmtFinType1','BsmtFinSF1','BsmtFinSF2','GarageCond','Fence','SaleType','MiscFeature'], axis='columns')
df2.shape
# Out:
# (1460, 52)

# %%
df2.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# LotArea           0
# Street            0
# LandContour       0
# Utilities         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# Exterior1st       0
# MasVnrType        8
# MasVnrArea        8
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtCond         37
# TotalBsmtSF       0
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        1
# 1stFlrSF          0
# 2ndFlrSF          0
# GrLivArea         0
# FullBath          0
# HalfBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# KitchenQual       0
# TotRmsAbvGrd      0
# Fireplaces        0
# GarageType       81
# GarageCars        0
# PavedDrive        0
# WoodDeckSF        0
# OpenPorchSF       0
# EnclosedPorch     0
# 3SsnPorch         0
# ...

# %%
df3 = df2.dropna(subset = ['Electrical'])
df4 = df3.fillna(0)
df4.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotArea          0
# Street           0
# LandContour      0
# Utilities        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# Exterior1st      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtCond         0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# GrLivArea        0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageType       0
# GarageCars       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df4.head()
# Out:
#    Id  MSSubClass  LotArea Street LandContour Utilities LandSlope  \
# 0   1          60     8450   Pave         Lvl    AllPub       Gtl
# 1   2          20     9600   Pave         Lvl    AllPub       Gtl
# 2   3          60    11250   Pave         Lvl    AllPub       Gtl
# 3   4          70     9550   Pave         Lvl    AllPub       Gtl
# 4   5          60    14260   Pave         Lvl    AllPub       Gtl
#
#   Neighborhood Condition1 BldgType HouseStyle  OverallQual  OverallCond  \
# 0      CollgCr       Norm     1Fam     2Story            7            5
# 1      Veenker      Feedr     1Fam     1Story            6            8
# 2      CollgCr       Norm     1Fam     2Story            7            5
# 3      Crawfor       Norm     1Fam     2Story            7            5
# 4      NoRidge       Norm     1Fam     2Story            8            5
#
#    YearBuilt  YearRemodAdd RoofStyle Exterior1st MasVnrType  MasVnrArea  \
# ...

# %%
type(df4['HalfBath'][3])
# Out:
# numpy.int64
